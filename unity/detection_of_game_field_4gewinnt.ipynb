# %%
import cv2
import numpy as np
import sys
import matplotlib.pyplot as plt
import glob
import time
import math
# %matplotlib inline

# %%
lst_fnames = glob.glob("./*_camImage.png")#598788_camImage.png

for fname in lst_fnames:
    img = cv2.imread(fname, cv2.IMREAD_COLOR)
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    
    hsv = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
    lower_blue = np.array([110,50,50])
    upper_blue = np.array([130,255,255])
  
    # Here we are defining range of bluecolor in HSV
    # This creates a mask of blue coloured 
    # objects found in the frame.
    mask = cv2.inRange(hsv, lower_blue, upper_blue)
    res = cv2.bitwise_and(img,img, mask= mask)
    
    
    '''
    # work on original image
    img = cv2.medianBlur(img,5)
    cimg = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)

    rows = cimg.shape[0]
    circles = cv2.HoughCircles(cimg, cv2.HOUGH_GRADIENT, 1.2, rows / 20, param1=30, param2=24, minRadius=10, maxRadius=15)
    circles = np.uint16(np.around(circles))
    img_copy = img.copy()
    '''
    '''
    #work on mask less reliable
    mask =cv2.medianBlur(mask,11)
    rows = mask.shape[0]
    circles = cv2.HoughCircles(mask, cv2.HOUGH_GRADIENT, 2, rows / 16, param1=100, param2=25, minRadius=10, maxRadius=20)
    circles = np.uint16(np.around(circles))
    img_copy = img.copy()
    '''
    # work on masked image
    res = cv2.medianBlur(res,11)
    cimg = cv2.cvtColor(res,cv2.COLOR_RGB2GRAY)
    plt.imshow(cimg, cmap="gray")
    plt.show()
    
    #extract connected components from the masked image
    copy_img1 = img.copy()
    
    thresh = cv2.threshold(cimg, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    # Creating kernel
    kernel = np.ones((3, 21), np.uint8)
  
    # Using cv2.erode() method 
    erode_img = cv2.erode(thresh[1], kernel)
    num_labels, labels, stats, centroids = cv2.connectedComponentsWithStats(erode_img , 8 , cv2.CV_32S)
    print ("Num_labels:",num_labels)
    count_circles = 0
    left_c = 1000
    right_c = 0
    top_c = 1000
    bottom_c = 0
    for i in range(0, num_labels):
            if (stats[i,-1]<1000):
                count_circles+=1
                if(left_c>=centroids[i][0]):
                    left_c = centroids[i][0]
                if(right_c<=centroids[i][0]):
                    right_c = centroids[i][0]
                if(top_c>=centroids[i][1]):
                    top_c = centroids[i][1]
                if(bottom_c<=centroids[i][1]):
                    bottom_c = centroids[i][1]
                #print(centroids[i])
    print ("Field objects:", count_circles)
    
    left_c = round(left_c)
    right_c = round(right_c)
    top_c = round(top_c)
    bottom_c = round(bottom_c)
    if(count_circles!= 42):
        print ("Something went wrong, not all circles were detected with CC")
    
            
    plt.imshow(erode_img, cmap="gray")
    plt.show()
    
    # and with hough circles (may be a bit parameters sensitive)
    rows = cimg.shape[0]
    circles = cv2.HoughCircles(cimg, cv2.HOUGH_GRADIENT, 1.2, rows / 20, param1=30, param2=19, minRadius=10, maxRadius=15)
    circles = np.uint16(np.around(circles))
    img_copy = img.copy()
    
    
    print ("Detected:", circles.shape[1], " in file:",fname )
    print ("field boundaries:",left_c,right_c,top_c,bottom_c)
    if(circles.shape[1]<42):
        print ("!!!!!PROBLEM!!! USE CONNECTED COMPONENTS!")
    else:
        for i in circles[0,:]:
            #check if this circle has an overlap with the 
            if(i[0]<left_c-5) or (i[0]>right_c+5) or(i[1]<top_c-5) or(i[1]>bottom_c+5):
                print("weird circle, avoid")
            else:
                #print(i[0],i[1])
                # draw the outer circle
                cv2.circle(img_copy,(i[0],i[1]),i[2],(0,255,0),2)
                # draw the center of the circle
                cv2.circle(img_copy,(i[0],i[1]),2,(0,0,255),3)
  
    
    plt.subplot(1, 2, 1)
    plt.imshow(img_copy)
    plt.subplot(1, 2, 2)
    plt.imshow(cimg, cmap="gray")
# Out:
# Num_labels: 44
# Field objects: 42
# Detected: 42  in file: ./598788_camImage.png
# field boundaries: 197 417 216 385
# Num_labels: 44
# Field objects: 42
# Detected: 42  in file: ./115259_camImage.png
# field boundaries: 233 452 211 380
# Num_labels: 44
# Field objects: 42
# Detected: 42  in file: ./700956_camImage.png
# field boundaries: 191 399 209 368
# Num_labels: 44
# Field objects: 42
# Detected: 42  in file: ./280148_camImage.png
# field boundaries: 246 465 213 380
# Num_labels: 44
# Field objects: 42
# Detected: 42  in file: ./161670_camImage.png
# field boundaries: 233 454 211 381
# Num_labels: 44
# Field objects: 42
# Detected: 42  in file: ./905177_camImage.png
# field boundaries: 228 449 210 381
# Num_labels: 44
# Field objects: 42
# Detected: 42  in file: ./459544_camImage.png
# field boundaries: 233 454 211 381
# Num_labels: 45
# Field objects: 42
# Detected: 42  in file: ./376119_camImage.png
# field boundaries: 199 416 229 395
# Num_labels: 44
# Field objects: 42
# ...
